# %%
import pandas
import numpy

os.chdir('C:\\Dania\\2024\\Australian Election')

DOP_data = read.csv("HouseDOPByDivisionDownload-27966")

#DOP_data.loc[DOP_data["CountNumber"] == 0 and DOP_data["CalculationType"] =="Preference Percent"]
DOP_data.head()
